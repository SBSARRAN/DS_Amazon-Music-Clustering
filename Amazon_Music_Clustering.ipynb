# %%
import pandas as pd
df = pd.read_csv(r'C:\Project_4\single_genre_artists.csv')
df.head()
# Out:
#                  id_songs         name_song  popularity_songs  duration_ms  \
# 0  0IA0Hju8CAgYfV1hwhidBH           La Java                 0       161427
# 1  1b8HZQCqcqwbzlA1jRTp6E          En Douce                 0       223440
# 2  5d5gQxHwYovxR5pqETOIAa     J'en Ai Marre                 0       208267
# 3  1EO65UEEPfy7CR0NK2sDxy  Ils n'ont pas ca                 0       161933
# 4  6a58gXSgqbIsXUhVZ6ZJqe         La belote                 0       167973
#
#    explicit              id_artists release_date  danceability  energy  key  \
# 0         0  4AxgXfD7ISvJSTObqm4aIE         1922         0.563   0.184    4
# 1         0  4AxgXfD7ISvJSTObqm4aIE         1922         0.427   0.180   10
# 2         0  4AxgXfD7ISvJSTObqm4aIE         1922         0.511   0.206    0
# 3         0  4AxgXfD7ISvJSTObqm4aIE         1924         0.676   0.467    9
# 4         0  4AxgXfD7ISvJSTObqm4aIE         1924         0.650   0.298    9
#
# ...

# %%
df.columns
# Out:
# Index(['id_songs', 'name_song', 'popularity_songs', 'duration_ms', 'explicit',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'followers', 'genres',
#        'name_artists', 'popularity_artists'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#                      id_songs          name_song  popularity_songs  \
# 0      0IA0Hju8CAgYfV1hwhidBH            La Java                 0
# 1      1b8HZQCqcqwbzlA1jRTp6E           En Douce                 0
# 2      5d5gQxHwYovxR5pqETOIAa      J'en Ai Marre                 0
# 3      1EO65UEEPfy7CR0NK2sDxy   Ils n'ont pas ca                 0
# 4      6a58gXSgqbIsXUhVZ6ZJqe          La belote                 0
# ...                       ...                ...               ...
# 95832  44r4zta6P9flkhKaVnbsvG             Freaks                70
# 95833  0MmaEacabpK8Yp3Mdeo5uY                下雨天                50
# 95834  1dKxf4Ht2SsKLyXfSDJAgy   The Cutest Puppy                67
# 95835  0SjsIzJkZfDU7wlcdklEFR  John Brown's Song                66
# 95836  5rgu12WBIHQtvej2MdHSH0                云与海                50
#
#        duration_ms  explicit              id_artists release_date  \
# 0           161427         0  4AxgXfD7ISvJSTObqm4aIE         1922
# ...

# %%
df.shape
# Out:
# (95837, 23)

# %%
df.describe()
# Out:
#        popularity_songs   duration_ms      explicit  danceability  \
# count      95837.000000  9.583700e+04  95837.000000  95837.000000
# mean          26.066394  2.087320e+05      0.029644      0.586853
# std           16.254133  1.177526e+05      0.169604      0.155422
# min            0.000000  6.373000e+03      0.000000      0.000000
# 25%           13.000000  1.573330e+05      0.000000      0.488000
# 50%           26.000000  2.040000e+05      0.000000      0.605000
# 75%           37.000000  2.502670e+05      0.000000      0.700000
# max           98.000000  4.800118e+06      1.000000      0.991000
#
#              energy           key      loudness          mode   speechiness  \
# count  95837.000000  95837.000000  95837.000000  95837.000000  95837.000000
# mean       0.541083      5.196782    -10.157862      0.648069      0.168832
# std        0.236304      3.534923      4.748798      0.477575      0.275417
# ...

# %%
df.isnull().sum()
# Out:
# id_songs              0
# name_song             0
# popularity_songs      0
# duration_ms           0
# explicit              0
# id_artists            0
# release_date          0
# danceability          0
# energy                0
# key                   0
# loudness              0
# mode                  0
# speechiness           0
# acousticness          0
# instrumentalness      0
# liveness              0
# valence               0
# tempo                 0
# time_signature        0
# followers             0
# genres                0
# name_artists          0
# popularity_artists    0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (95837, 23)

# %%
df.columns
# Out:
# Index(['id_songs', 'name_song', 'popularity_songs', 'duration_ms', 'explicit',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'followers', 'genres',
#        'name_artists', 'popularity_artists'],
#       dtype='object')

# %%
# Now we dropping the Unique Features
df = df.drop(columns=['id_songs','name_song','id_artists','release_date',
                      'name_artists','genres','key','mode',
                      'explicit','time_signature','followers','popularity_artists'])

# %%
df.shape
# Out:
# (95837, 11)

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#        popularity_songs  duration_ms  danceability  energy  loudness  \
# 0                     0       161427         0.563  0.1840   -13.757
# 1                     0       223440         0.427  0.1800   -15.375
# 2                     0       208267         0.511  0.2060   -15.514
# 3                     0       161933         0.676  0.4670   -12.393
# 4                     0       167973         0.650  0.2980   -13.806
# ...                 ...          ...           ...     ...       ...
# 95832                70       174800         0.674  0.5680    -6.356
# 95833                50       265846         0.528  0.6730    -3.639
# 95834                67        82500         0.609  0.0172   -28.573
# 95835                66       185250         0.562  0.0331   -25.551
# 95836                50       258267         0.560  0.5180    -7.471
#
#        speechiness  acousticness  instrumentalness  liveness  valence    tempo
# ...

# %%
df.dtypes
# Out:
# popularity_songs      int64
# duration_ms           int64
# danceability        float64
# energy              float64
# loudness            float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# dtype: object

# %%
df.columns
# Out:
# Index(['popularity_songs', 'duration_ms', 'danceability', 'energy', 'loudness',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo'],
#       dtype='object')

# %%
num_cols = ['duration_ms','danceability','energy','loudness','popularity_songs',
            'speechiness','acousticness','instrumentalness','liveness','valence','tempo']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15, 12))
for i, col in enumerate(num_cols, 1):
    plt.subplot(5, 3, i)
    sns.boxplot(data=df, y=col)
    plt.title(f'{col} (skewness : {df[col].skew():.3f})')
plt.suptitle('Features Before Processing', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
import numpy as np
for i in num_cols:
    if (df[i] > 0).all():
        if df[i].skew() > 1:
            df[i] = np.log1p(df[i])
    elif df[i].skew() < -1:
        df[i] = np.power(df[i], 2)

# %%
# After applying log to skewness
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15, 12))
for i, col in enumerate(num_cols, 1):
    plt.subplot(5, 3, i)
    sns.boxplot(data=df, y=col)
    plt.title(f'{col} (skewness : {df[col].skew():.3f})')
plt.suptitle('Features after Processing', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
df.hist(figsize=(12,10),bins=30,edgecolor = 'black')
plt.suptitle("Distribution of Features ",fontsize=15)
plt.show()

# %%
df
# Out:
#        popularity_songs  duration_ms  danceability  energy    loudness  \
# 0                     0    11.991815         0.563  0.1840  189.255049
# 1                     0    12.316903         0.427  0.1800  236.390625
# 2                     0    12.246581         0.511  0.2060  240.684196
# 3                     0    11.994944         0.676  0.4670  153.586449
# 4                     0    12.031564         0.650  0.2980  190.605636
# ...                 ...          ...           ...     ...         ...
# 95832                70    12.071403         0.674  0.5680   40.398736
# 95833                50    12.490676         0.528  0.6730   13.242321
# 95834                67    11.320566         0.609  0.0172  816.416329
# 95835                66    12.129467         0.562  0.0331  652.853601
# 95836                50    12.461753         0.560  0.5180   55.815841
#
#        speechiness  acousticness  instrumentalness  liveness  valence    tempo
# ...

# %%
from sklearn.preprocessing import StandardScaler
X = df[num_cols].copy()
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)
df_scaled
# Out:
# array([[-1.60368627, -0.31134471, -0.15347598, ...,  0.53858362,
#          0.32128698,  0.51500516],
#        [-1.60368627,  0.36871755, -1.02851842, ..., -0.52153664,
#         -0.57745518, -1.2944868 ],
#        [-1.60368627,  0.22160939, -0.48805103, ...,  1.03904648,
#         -0.37594348, -1.56000306],
#        ...,
#        [ 2.51836375, -1.71555138,  0.14249425, ..., -0.62916306,
#          1.27242218, -1.62041993],
#        [ 2.45684062, -0.02338521, -0.15991012, ..., -0.6130191 ,
#         -0.7588157 , -1.78348586],
#        [ 1.47247047,  0.67173471, -0.17277839, ..., -0.86163613,
#         -1.46410663,  0.47552221]])

# %%
# Find the best K using Elbow Method
from sklearn.cluster import KMeans
inertia = []
K_value = range(2, 11)  

for k in K_value:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)
    print('K value = ', k, 'Inertia value = ', kmeans.inertia_)

plt.plot(K_value, inertia, 'bx-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia (SSE)')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# K value =  2 Inertia value =  869716.7336129675
# K value =  3 Inertia value =  729881.439694906
# K value =  4 Inertia value =  662794.9256136593
# K value =  5 Inertia value =  618100.45327933
# K value =  6 Inertia value =  586808.0368675822
# K value =  7 Inertia value =  555118.519553919
# K value =  8 Inertia value =  544381.0696768411
# K value =  9 Inertia value =  507849.14011977345
# K value =  10 Inertia value =  494429.57400556456

# %%
# Evaluate the silhouette score
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
scores = []
for k in range(2,11):
    kmeans = KMeans(n_clusters=k,random_state=42)
    kmeans.fit(df_scaled)
    score = silhouette_score(df_scaled,kmeans.labels_)
    scores.append(score)
plt.plot(range(2,11),scores,'bx-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method for Optimal k')
plt.show()

# %%
# silhouette score from K values
scores
# Out:
# [0.19529932312250253,
#  0.22763247439389747,
#  0.21084582289784598,
#  0.16520189593605145,
#  0.16824710973122745,
#  0.15817051431795726,
#  0.13781212310100996,
#  0.15480856071784643,
#  0.14437583394716721]

# %%
# After Elbow Methot and Silhouette Method the best K = 3
# So the best K value is 3
kmeans = KMeans(n_clusters=3,random_state=42)
kmeans.fit(df_scaled)
df['cluster_KMEANS'] = kmeans.labels_

# %%
# Evaluate the K_Means
from sklearn.metrics import silhouette_score,davies_bouldin_score
sil_score = silhouette_score(df_scaled,df['cluster_KMEANS'])
davies_score = davies_bouldin_score(df_scaled,df['cluster_KMEANS'])
print(f'silhouette_score = {sil_score}')
print(f'davies_bouldin_score = {davies_score}')
# Out:
# silhouette_score = 0.22763247439389747
# davies_bouldin_score = 1.656657717302999

# %%
df['cluster_KMEANS'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 95832    1
# 95833    1
# 95834    0
# 95835    0
# 95836    0
# Name: cluster_KMEANS, Length: 95837, dtype: int32>

# %%
cluster_summary = df.groupby('cluster_KMEANS').mean()
cluster_summary
# Out:
#                 popularity_songs  duration_ms  danceability    energy  \
# cluster_KMEANS
# 0                      18.542378    12.218974      0.484299  0.309831
# 1                      29.741726    12.289914      0.626427  0.688635
# 2                      28.448235    11.326025      0.663637  0.468605
#
#                   loudness  speechiness  acousticness  instrumentalness  \
# cluster_KMEANS
# 0               199.687598     0.064030      0.764859          0.174118
# 1                68.023944     0.073879      0.257690          0.049266
# 2               193.226376     0.817540      0.580696          0.002285
#
#                 liveness   valence       tempo
# cluster_KMEANS
# 0               0.185851  0.424354  111.746841
# 1               0.198688  0.656271  124.812385
# 2               0.428117  0.584873  100.662136

# %%
df.columns
# Out:
# Index(['popularity_songs', 'duration_ms', 'danceability', 'energy', 'loudness',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'cluster_KMEANS'],
#       dtype='object')

# %%
cluster_summary.T.plot(kind='bar', figsize=(12,6))
plt.title('Average Feature Values per Cluster')
plt.ylabel('Scaled Feature Value')
plt.show()

# %%
features = ['danceability', 'energy', 'valence', 'acousticness', 'speechiness','instrumentalness','liveness']
cluster_summary[features].T.plot(kind='bar', figsize=(12,6))
plt.title('Key Audio Features per Cluster')
plt.ylabel('Scaled Value')
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_data = pca.fit_transform(df_scaled)
centroids = pca.transform(kmeans.cluster_centers_)

plt.figure(figsize=(8,6))
plt.scatter(pca_data[:,0], pca_data[:,1], c=df['cluster_KMEANS'], cmap='viridis', alpha=0.6)
plt.scatter(centroids[:,0], centroids[:,1], c='red', s=200, marker='X', label='Centroids')
plt.title('Clusters Visualized using PCA with Centroids')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.legend()
plt.show()

# %%
# Unsupervised Learning using DBSCAN
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.8,min_samples=8)
dbscan.fit(df_scaled)
df['cluster_DBSCAN'] = dbscan.labels_

# %%
df['cluster_DBSCAN'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        0
# 1        0
# 2       -1
# 3       -1
# 4       -1
#         ..
# 95832   -1
# 95833    0
# 95834   -1
# 95835   -1
# 95836    0
# Name: cluster_DBSCAN, Length: 95837, dtype: int64>

# %%
cluster_summary_dbscan = df.groupby('cluster_DBSCAN').mean()
cluster_summary_dbscan
# Out:
#                 popularity_songs  duration_ms  danceability    energy  \
# cluster_DBSCAN
# -1                     24.897650    12.077803      0.559238  0.503922
#  0                     27.297576    12.302198      0.608694  0.595204
#  1                      6.500000    12.010862      0.685143  0.302714
#  2                      1.172249    12.085206      0.668861  0.369502
#  3                      1.125000    12.047219      0.541125  0.341875
# ...                          ...          ...           ...       ...
#  72                    37.250000    12.530117      0.374750  0.296750
#  73                    11.571429    12.320985      0.294714  0.842286
#  74                    25.142857    12.515192      0.337429  0.538143
#  75                    21.500000    12.130667      0.371750  0.097550
#  76                    39.000000    12.400850      0.384000  0.513333
#
#                   loudness  speechiness  acousticness  instrumentalness  \
# cluster_DBSCAN
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(cluster_summary_dbscan, cmap='coolwarm', center=0)
plt.title('DBSCAN Cluster Feature Heatmap')
plt.show()

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(df_scaled,df['cluster_DBSCAN'])
score
# Out:
# -0.44438961258146553
